# %% [markdown]
# # Arizona Housing Market Dashboard Data
#
# ##### Goal: Analyze Arizona's largest real-estate markets.
#
# #### Steps:
#         1. Extract Redfin Data
#         2. Transform tables
#         3. Load to Power BI

# %% [markdown]
# # 1. Extracting Data from Redfin

# %%
import pandas as pd

#Redfin Data Source - https://www.redfin.com/news/data-center/
url = 'https://redfin-public-data.s3.us-west-2.amazonaws.com/redfin_market_tracker/zip_code_market_tracker.tsv000.gz'

#Retrieving entire redfin data set
redfin_data_all_states = pd.read_csv(url, compression='gzip', sep='\t')

# %% [markdown]
# ### 1.1 Mapping Redfin Zip Codes to U.S. Cities

# %%
#Creating a new table to map zip codes to county/city
mapping_df = pd.read_csv('https://raw.githubusercontent.com/scpike/us-state-county-zip/master/geo-data.csv')

mapping_df  = (mapping_df
                        .assign(
                            zipcode = mapping_df['zipcode'].loc[mapping_df['zipcode'].str.isnumeric()].astype(int))
                        .drop(columns=['state_fips'])
                        .dropna()
                )

# %% [markdown]
# # 2. Transforming Tables (slicing, cleaning, merging)

# %%
#Arizona housing data
az_redfin_df = (redfin_data_all_states
                .loc[redfin_data_all_states['state_code'] == 'AZ']
                .assign(
                    zipcode = redfin_data_all_states['region'].str.replace('Zip Code:','').astype(int),
                    median_dom_mom = redfin_data_all_states.sort_values(by = ['period_begin'])['median_dom'].pct_change()
                    )
                .merge(mapping_df, on = 'zipcode', how = 'inner')
                .drop(columns = ['region','city_x','state_x'])
                .rename(columns = {'city_y':'city','state_y':'state'})
                )
# Out:
#       period_begin  period_end  period_duration region_type  region_type_id  \
# 0       2018-06-01  2018-08-31               90    zip code               2
# 1       2019-12-01  2020-02-29               90    zip code               2
# 2       2021-11-01  2022-01-31               90    zip code               2
# 3       2014-10-01  2014-12-31               90    zip code               2
# 4       2018-04-01  2018-06-30               90    zip code               2
# ...            ...         ...              ...         ...             ...
# 92495   2019-03-01  2019-05-31               90    zip code               2
# 92496   2019-01-01  2019-03-31               90    zip code               2
# 92497   2019-01-01  2019-03-31               90    zip code               2
# 92498   2019-02-01  2019-04-30               90    zip code               2
# 92499   2019-02-01  2019-04-30               90    zip code               2
#
#        table_id is_seasonally_adjusted state_code              property_type  \
# 0         36530                      f         AZ            All Residential
# 1         36530                      f         AZ                Condo/Co-op
# 2         36530                      f         AZ                  Townhouse
# 3         36530                      f         AZ                  Townhouse
# 4         36530                      f         AZ                  Townhouse
# ...         ...                    ...        ...                        ...
# 92495     36283                      f         AZ            All Residential
# 92496     36283                      f         AZ  Single Family Residential
# 92497     36283                      f         AZ            All Residential
# 92498     36283                      f         AZ            All Residential
# 92499     36283                      f         AZ  Single Family Residential
#
#        property_type_id  ...  off_market_in_two_weeks_mom  \
# 0                    -1  ...                     0.052533
# 1                     3  ...                     0.000000
# 2                    13  ...                    -0.666667
# 3                    13  ...                    -0.500000
# 4                    13  ...                     0.000000
# ...                 ...  ...                          ...
# 92495                -1  ...                          NaN
# 92496                 6  ...                          NaN
# 92497                -1  ...                          NaN
# 92498                -1  ...                          NaN
# 92499                 6  ...                          NaN
#
#        off_market_in_two_weeks_yoy  parent_metro_region  \
# 0                        -0.040724           Tucson, AZ
# 1                        -0.500000           Tucson, AZ
# 2                         0.000000           Tucson, AZ
# 3                         0.000000           Tucson, AZ
# 4                        -0.250000           Tucson, AZ
# ...                            ...                  ...
# 92495                          NaN          Phoenix, AZ
# 92496                          NaN          Phoenix, AZ
# 92497                          NaN          Phoenix, AZ
# 92498                          NaN          Phoenix, AZ
# 92499                          NaN          Phoenix, AZ
#
#        parent_metro_region_metro_code         last_updated  zipcode    state  \
# 0                               46060  2022-07-10 14:38:35    85737  Arizona
# 1                               46060  2022-07-10 14:38:35    85737  Arizona
# 2                               46060  2022-07-10 14:38:35    85737  Arizona
# 3                               46060  2022-07-10 14:38:35    85737  Arizona
# 4                               46060  2022-07-10 14:38:35    85737  Arizona
# ...                               ...                  ...      ...      ...
# 92495                           38060  2022-07-10 14:38:35    85232  Arizona
# 92496                           38060  2022-07-10 14:38:35    85232  Arizona
# 92497                           38060  2022-07-10 14:38:35    85232  Arizona
# 92498                           38060  2022-07-10 14:38:35    85232  Arizona
# 92499                           38060  2022-07-10 14:38:35    85232  Arizona
#
#        state_abbr  county        city
# 0              AZ    Pima  Oro valley
# 1              AZ    Pima  Oro valley
# 2              AZ    Pima  Oro valley
# 3              AZ    Pima  Oro valley
# 4              AZ    Pima  Oro valley
# ...           ...     ...         ...
# 92495          AZ   Pinal    Florence
# 92496          AZ   Pinal    Florence
# 92497          AZ   Pinal    Florence
# 92498          AZ   Pinal    Florence
# 92499          AZ   Pinal    Florence
#
# [92500 rows x 60 columns]

# %% [markdown]
# # 3. Loading data into Power BI
#
# Note: As Power BI will not allow us to retrieve more than 2gb of data using a python script. We will download our data into a .csv.

# %%
az_redfin_df.to_csv(r'C:\Users\Dan\Desktop\Coding\Datasets\Redfin_Data\Redfin_Zip_Realtor_Data.csv')
